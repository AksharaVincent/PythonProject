# %%
import pandas as pd
import numpy as np

student=pd.read_csv('StudentsPerformance1.csv')
student
# Out:
#       Student ID  gender race/ethnicity parental level of education  \
# 0              1  female        group B           bachelor's degree
# 1              2  female        group C                     Diploma
# 2              3  female        group B             master's degree
# 3              4    male        group A          associate's degree
# 4              5    male        group C                     Diploma
# ...          ...     ...            ...                         ...
# 1000        1001  female        group E             master's degree
# 1001        1002    male        group C                 high school
# 1002        1003  female        group C                 high school
# 1003        1004  female        group D                     Diploma
# 1004        1005  female        group D                     Diploma
#
#              lunch  Column  Column.1 test preparation course  math score  \
# 0         standard     NaN       NaN                    none        72.0
# ...

# %%
student.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1005 entries, 0 to 1004
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Student ID                   1005 non-null   int64
#  1   gender                       1005 non-null   object
#  2   race/ethnicity               1005 non-null   object
#  3   parental level of education  1005 non-null   object
#  4   lunch                        1005 non-null   object
#  5   Column                       0 non-null      float64
#  6   Column.1                     0 non-null      float64
#  7   test preparation course      1005 non-null   object
#  8   math score                   1000 non-null   float64
#  9   reading score                1000 non-null   float64
#  10  writing score                1000 non-null   float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 86.5+ KB

# %%
student.shape
# Out:
# (1005, 11)

# %% [markdown]
# ### 1. check whether null values are present in the given data. NO/YES

# %%
#YES

# %%
#dropping using drop()

#data1.drop(['Column'], axis = 1)

# %%
student1=student.copy()
student1
# Out:
#       Student ID  gender race/ethnicity parental level of education  \
# 0              1  female        group B           bachelor's degree
# 1              2  female        group C                     Diploma
# 2              3  female        group B             master's degree
# 3              4    male        group A          associate's degree
# 4              5    male        group C                     Diploma
# ...          ...     ...            ...                         ...
# 1000        1001  female        group E             master's degree
# 1001        1002    male        group C                 high school
# 1002        1003  female        group C                 high school
# 1003        1004  female        group D                     Diploma
# 1004        1005  female        group D                     Diploma
#
#              lunch  Column  Column.1 test preparation course  math score  \
# 0         standard     NaN       NaN                    none        72.0
# ...

# %%
student1.drop(['Column', 'Column.1'], axis = 1,inplace=True)

# %%
#add a variable total score

student1['Total Score']=student1['math score']+student1['reading score']+student1['writing score']
student1
# Out:
#       Student ID  gender race/ethnicity parental level of education  \
# 0              1  female        group B           bachelor's degree
# 1              2  female        group C                     Diploma
# 2              3  female        group B             master's degree
# 3              4    male        group A          associate's degree
# 4              5    male        group C                     Diploma
# ...          ...     ...            ...                         ...
# 1000        1001  female        group E             master's degree
# 1001        1002    male        group C                 high school
# 1002        1003  female        group C                 high school
# 1003        1004  female        group D                     Diploma
# 1004        1005  female        group D                     Diploma
#
#              lunch test preparation course  math score  reading score  \
# 0         standard                    none        72.0           72.0
# ...

# %%
student1.isna().sum()
# Out:
# Student ID                     0
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     5
# reading score                  5
# writing score                  5
# Total Score                    5
# dtype: int64

# %%
student1.median()
# Out:
# C:\Users\vantl\AppData\Local\Temp\ipykernel_1940\4059838626.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   student1.median()
# Student ID       503.0
# math score        66.0
# reading score     70.0
# writing score     69.0
# Total Score      205.0
# dtype: float64

# %%
#student=student.fillna().mean()
#student.head(3)
student1.median()
student2=student1.fillna(student.median())
student2
# Out:
# C:\Users\vantl\AppData\Local\Temp\ipykernel_1940\2528063952.py:3: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   student1.median()
# C:\Users\vantl\AppData\Local\Temp\ipykernel_1940\2528063952.py:4: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   student2=student1.fillna(student.median())
#       Student ID  gender race/ethnicity parental level of education  \
# 0              1  female        group B           bachelor's degree
# 1              2  female        group C                     Diploma
# ...

# %%
student2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1005 entries, 0 to 1004
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Student ID                   1005 non-null   int64
#  1   gender                       1005 non-null   object
#  2   race/ethnicity               1005 non-null   object
#  3   parental level of education  1005 non-null   object
#  4   lunch                        1005 non-null   object
#  5   test preparation course      1005 non-null   object
#  6   math score                   1005 non-null   float64
#  7   reading score                1005 non-null   float64
#  8   writing score                1005 non-null   float64
#  9   Total Score                  1000 non-null   float64
# dtypes: float64(4), int64(1), object(5)
# memory usage: 78.6+ KB

# %% [markdown]
# ### 2.find the total number of students.

# %%
student2['Student ID'].value_counts().sum()
# Out:
# 1005

# %% [markdown]
# ### 3. find the average for reading score

# %%
student2['reading score'].mean()
# Out:
# 69.1731343283582

# %% [markdown]
# ### 4.check the descriptive statistics for writing score

# %%
student2.describe()['writing score']
# Out:
# count    1005.000000
# mean       68.058706
# std        15.157918
# min        10.000000
# 25%        58.000000
# 50%        69.000000
# 75%        79.000000
# max       100.000000
# Name: writing score, dtype: float64

# %% [markdown]
# ### 5.find how many students had completed the test

# %%
student2['test preparation course'].value_counts()
# Out:
# none         644
# completed    361
# Name: test preparation course, dtype: int64

# %%
#completed=361

# %% [markdown]
# ### 6.find the min score in math

# %%
student2.min()['math score']
# Out:
# 0.0

# %% [markdown]
# ### 7.find the max score in writing

# %%
student2.max()['writing score']
# Out:
# 100.0

# %% [markdown]
# ### 8.find the number of students by lunch

# %%
e=student2.groupby('lunch').count()['Student ID']
e
# Out:
# lunch
# free/reduced    356
# standard        649
# Name: Student ID, dtype: int64

# %% [markdown]
# ### 9.find the average score for each by race/ethnicity.

# %%
e=student2.groupby('race/ethnicity').mean()['Total Score']
e
# Out:
# C:\Users\vantl\AppData\Local\Temp\ipykernel_1940\4206370976.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   e=student2.groupby('race/ethnicity').mean()['Total Score']
# race/ethnicity
# group A    188.977528
# group B    196.405263
# group C    201.394984
# group D    207.538168
# group E    218.257143
# Name: Total Score, dtype: float64

# %% [markdown]
# ### 10.create a count plot for parental level of education.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
student2['parental level of education'].value_counts()
# Out:
# high school           376
# Diploma               227
# associate's degree    223
# bachelor's degree     119
# master's degree        60
# Name: parental level of education, dtype: int64

# %%
student2['parental level of education'].value_counts(normalize=True)
student2['parental level of education'].value_counts(dropna=False).plot.bar(color='lime')
plt.title('Comparison of parental level of education')
plt.xlabel('parental level of education')
plt.ylabel('parental level of education')
plt.show()

# %% [markdown]
# ### 11. Find the total score of each student

# %%
student2.groupby('Student ID').sum()['Total Score']
# Out:
# C:\Users\vantl\AppData\Local\Temp\ipykernel_1940\1861250810.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   student2.groupby('Student ID').sum()['Total Score']
# Student ID
# 1       218.0
# 2       247.0
# 3       278.0
# 4       148.0
# 5       229.0
#         ...
# 1001    282.0
# 1002    172.0
# 1003    195.0
# 1004    223.0
# 1005    249.0
# Name: Total Score, Length: 1005, dtype: float64

# %% [markdown]
# ### 12.What is the average of total score for male and female students?

# %%
student2.groupby('gender').mean()['Total Score']
# Out:
# C:\Users\vantl\AppData\Local\Temp\ipykernel_1940\3864007596.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   student2.groupby('gender').mean()['Total Score']
# gender
# female    208.708494
# male      197.512448
# Name: Total Score, dtype: float64

# %% [markdown]
# ### 13. What is the average of total score by gender and parental education level?

# %%
student2.groupby(['gender','parental level of education']).mean()['Total Score']
# Out:
# C:\Users\vantl\AppData\Local\Temp\ipykernel_1940\1523250786.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   student2.groupby(['gender','parental level of education']).mean()['Total Score']
# gender  parental level of education
# female  Diploma                        213.008475
#         associate's degree             213.370690
#         bachelor's degree              224.015873
#         high school                    195.448649
#         master's degree                220.944444
# male    Diploma                        197.148148
#         associate's degree             203.603774
#         bachelor's degree              206.327273
#         high school                    188.978947
#         master's degree                220.565217
# Name: Total Score, dtype: float64

# %% [markdown]
# ### 14. What is the average math score by race/ethnicity?

# %%
student2.groupby('race/ethnicity').mean()['math score']
# Out:
# C:\Users\vantl\AppData\Local\Temp\ipykernel_1940\3556324479.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   student2.groupby('race/ethnicity').mean()['math score']
# race/ethnicity
# group A    61.725275
# group B    63.465969
# group C    64.468750
# group D    67.362595
# group E    73.765957
# Name: math score, dtype: float64

# %% [markdown]
# ### 15.Find the number of Students by test preparation course

# %%
student2.groupby('test preparation course').count()['Student ID']
# Out:
# test preparation course
# completed    361
# none         644
# Name: Student ID, dtype: int64

# %% [markdown]
# ### 16. Find the average total score by test preparation cours

# %%
student2.groupby('test preparation course').mean()['Total Score']
# Out:
# C:\Users\vantl\AppData\Local\Temp\ipykernel_1940\2159904476.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   student2.groupby('test preparation course').mean()['Total Score']
# test preparation course
# completed    218.008380
# none         195.116822
# Name: Total Score, dtype: float64

# %% [markdown]
# ### 17. create a new variable as, 'Score', and the values in the column should be the sum of all the three papers

# %%
student2['Total Score']=(student2['math score']+student2['reading score']+student2['writing score'])
student2
# Out:
#       Student ID  gender race/ethnicity parental level of education  \
# 0              1  female        group B           bachelor's degree
# 1              2  female        group C                     Diploma
# 2              3  female        group B             master's degree
# 3              4    male        group A          associate's degree
# 4              5    male        group C                     Diploma
# ...          ...     ...            ...                         ...
# 1000        1001  female        group E             master's degree
# 1001        1002    male        group C                 high school
# 1002        1003  female        group C                 high school
# 1003        1004  female        group D                     Diploma
# 1004        1005  female        group D                     Diploma
#
#              lunch test preparation course  math score  reading score  \
# 0         standard                    none        72.0           72.0
# ...

# %% [markdown]
# ### 18. create a new variable as, " Percentage", and find the percentage for the score

# %%
student2['percentage'] = student1['Total Score']/3
student2
# Out:
#       Student ID  gender race/ethnicity parental level of education  \
# 0              1  female        group B           bachelor's degree
# 1              2  female        group C                     Diploma
# 2              3  female        group B             master's degree
# 3              4    male        group A          associate's degree
# 4              5    male        group C                     Diploma
# ...          ...     ...            ...                         ...
# 1000        1001  female        group E             master's degree
# 1001        1002    male        group C                 high school
# 1002        1003  female        group C                 high school
# 1003        1004  female        group D                     Diploma
# 1004        1005  female        group D                     Diploma
#
#              lunch test preparation course  math score  reading score  \
# 0         standard                    none        72.0           72.0
# ...

# %% [markdown]
# ### 19. create a new variable called, 'status'. Inside this column, find the status as Pass \ Fail, those who score above 40 % will pass the exam

# %%
#pass mark is 40 for each paper
passmark=40
 
student2['Status']=np.where(student2['percentage']<passmark,'Fail','Pass')
student2
# Out:
#       Student ID  gender race/ethnicity parental level of education  \
# 0              1  female        group B           bachelor's degree
# 1              2  female        group C                     Diploma
# 2              3  female        group B             master's degree
# 3              4    male        group A          associate's degree
# 4              5    male        group C                     Diploma
# ...          ...     ...            ...                         ...
# 1000        1001  female        group E             master's degree
# 1001        1002    male        group C                 high school
# 1002        1003  female        group C                 high school
# 1003        1004  female        group D                     Diploma
# 1004        1005  female        group D                     Diploma
#
#              lunch test preparation course  math score  reading score  \
# 0         standard                    none        72.0           72.0
# ...

# %% [markdown]
# ## 20. create a pie chart using the status column

# %%
student2['Status'].value_counts().plot(kind="pie", autopct='%1.2f%%')
# Out:
# <Axes: ylabel='Status'>
