# %%
#python_weather
import numpy as np
import pandas as pd

# %%
dict_line={'Temperature':[34,27,33,33,33,31,32,32,33,33],'Day':['Mon 08','Mon 08','Tue 09','Wed 10','Thu 11','Fri 12','Sat 13','Sun 14','Mon 15','Tue 16']}
b_line=pd.DataFrame(dict_line)
b_line
# Out:
#    Temperature     Day
# 0           34  Mon 08
# 1           27  Mon 08
# 2           33  Tue 09
# 3           33  Wed 10
# 4           33  Thu 11
# 5           31  Fri 12
# 6           32  Sat 13
# 7           32  Sun 14
# 8           33  Mon 15
# 9           33  Tue 16

# %%
#use plot() method on the dataframe
b_line.plot('Day','Temperature');
