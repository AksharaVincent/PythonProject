# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
ele=pd.read_excel('Indian_Parliament_elections.xlsx')
ele
# Out:
#                                        Political Party  No of Candidates  \
# 0                                Bharatiya Lok Dal BLD                 3
# 1                         Communist Party of India CPI                 4
# 2               Communist Party of India (Marxist) CPM                 9
# 3               Indian National Congress (Indira) INCI                11
# 4                            Others / Independents IND                23
# ..                                                 ...               ...
# 186                   Secular Democratic Congress SDC                  2
# 187             Social Democratic Party of India SDPI                 10
# 188                       Samajwadi Forward Block SFB                  1
# 189   Socialist Unity Centre of India (Communist) S...                 9
# 190                Viduthalai Chirutahikal Katchi VCK                  1
#
#      Seats Won    Votes  Percentage  year  Unnamed: 6 Unnamed: 7
# ...

# %%
ele.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191 entries, 0 to 190
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Political Party   191 non-null    object
#  1   No of Candidates  191 non-null    int64
#  2   Seats Won         191 non-null    int64
#  3   Votes             191 non-null    int64
#  4   Percentage        191 non-null    float64
#  5   year              191 non-null    int64
#  6   Unnamed: 6        0 non-null      float64
#  7   Unnamed: 7        1 non-null      object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 12.1+ KB

# %%
ele.shape
# Out:
# (191, 8)

# %%
ele.isna().sum()
# Out:
# Political Party       0
# No of Candidates      0
# Seats Won             0
# Votes                 0
# Percentage            0
# year                  0
# Unnamed: 6          191
# Unnamed: 7          190
# dtype: int64

# %% [markdown]
# ### 1.Check is there any null values in the data. Yes/ No

# %%
#Yes

# %%
ele.drop(['Unnamed: 6','Unnamed: 7'],axis=1,inplace=True)

# %%
ele1=ele.copy()
ele1
# Out:
#                                        Political Party  No of Candidates  \
# 0                                Bharatiya Lok Dal BLD                 3
# 1                         Communist Party of India CPI                 4
# 2               Communist Party of India (Marxist) CPM                 9
# 3               Indian National Congress (Indira) INCI                11
# 4                            Others / Independents IND                23
# ..                                                 ...               ...
# 186                   Secular Democratic Congress SDC                  2
# 187             Social Democratic Party of India SDPI                 10
# 188                       Samajwadi Forward Block SFB                  1
# 189   Socialist Unity Centre of India (Communist) S...                 9
# 190                Viduthalai Chirutahikal Katchi VCK                  1
#
#      Seats Won    Votes  Percentage  year
# 0            0   637206        7.19  1977
# ...

# %% [markdown]
# ### 1. Find the total number of party

# %%
ele1['Political Party'].count()
# Out:
# 191

# %% [markdown]
# ### 2. how many  number of party

# %%
ele1['Political Party'].value_counts()
# Out:
# Communist Party of India (Marxist) CPM                 4
# Indian National Congress (Indira) INCI                 4
# Others / Independents IND                              4
# Indian Union Muslim League IUML                        4
#  Bharatiya Janata Party BJP                            4
#                                                       ..
#   Indian National Congress (Indira) INCI               1
#  Independents DLP                                      1
#   Communist Party of India (Marxist-Leninist) CPML     1
#  UDF supported Independents UDF                        1
#  Samajwadi Forward Block SFB                           1
# Name: Political Party, Length: 122, dtype: int64

# %% [markdown]
# ### 3. Find the Unique number of party

# %%
ele1['Political Party'].value_counts()
# Out:
# Communist Party of India (Marxist) CPM                 4
# Indian National Congress (Indira) INCI                 4
# Others / Independents IND                              4
# Indian Union Muslim League IUML                        4
#  Bharatiya Janata Party BJP                            4
#                                                       ..
#   Indian National Congress (Indira) INCI               1
#  Independents DLP                                      1
#   Communist Party of India (Marxist-Leninist) CPML     1
#  UDF supported Independents UDF                        1
#  Samajwadi Forward Block SFB                           1
# Name: Political Party, Length: 122, dtype: int64

# %%
u1=ele1['Political Party'].unique()
len(np.unique(u1))
# Out:
# 122

# %% [markdown]
# ### 4.Find the total number of party in each year

# %%
ele1['year'].value_counts()
# Out:
# 2014    28
# 2019    27
# 2009    25
# 2004    21
# 1999    18
# 1998    17
# 1984    16
# 1986    15
# 1980    13
# 1977    11
# Name: year, dtype: int64

# %% [markdown]
# ### 5.Find the total number of party in each votes and year

# %%
ele1.groupby(['Votes','year']).count()['No of Candidates'].tail()
# Out:
# Votes    year
# 5590285  2014    1
# 6051905  1999    1
# 6217161  1986    1
# 6434486  2009    1
# 7596610  2019    1
# Name: No of Candidates, dtype: int64

# %% [markdown]
# ### 6.Find maximum votes

# %%
ele1['Votes'].max()
# Out:
# 7596610

# %% [markdown]
# ### 7.Find Minimum votes

# %%
ele1['Votes'].min()
# Out:
# 261

# %% [markdown]
# ### 8.Find the range of votes

# %%
#range=max-min

Range = 7596610 - 261
Range
# Out:
# 7596349

# %% [markdown]
# ### 9. Find the average of votes

# %%
ele1['Votes'].mean()
# Out:
# 741526.0052356021

# %% [markdown]
# ### 10.Find the standard deviation of votes

# %%
ele1['Votes'].std()
# Out:
# 1391167.1128395314

# %% [markdown]
# ### 11.Find Average votes by each No of Candidates

# %%
ele1.groupby('Votes').mean()['No of Candidates']
# Out:
# C:\Users\vantl\AppData\Local\Temp\ipykernel_1804\2478216145.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ele1.groupby('Votes').mean()['No of Candidates']
# Votes
# 261         1.0
# 320         1.0
# 379         1.0
# 457         1.0
# 546         1.0
#            ...
# 5590285    15.0
# 6051905    17.0
# 6217161    17.0
# 6434486    17.0
# 7596610    16.0
# Name: No of Candidates, Length: 191, dtype: float64

# %% [markdown]
# ### 12.check the descriptive for Seats Won

# %%
ele1['Seats Won'].describe()
# Out:
# count    191.000000
# mean       1.047120
# std        2.715042
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max       15.000000
# Name: Seats Won, dtype: float64

# %% [markdown]
# ### 13.check the descriptive for Percentage

# %%
ele1['Percentage'].describe()
# Out:
# count     191.000000
# mean       26.485916
# std       207.108900
# min         0.000000
# 25%         0.060000
# 50%         2.070000
# 75%         5.470000
# max      2053.000000
# Name: Percentage, dtype: float64

# %% [markdown]
# ### 14.Find the total number of party in each year,Percentage and Votes

# %%
ele1.groupby(['year','Percentage','Votes']).count()['Political Party']
# Out:
# year  Percentage  Votes
# 1977  2.42        214261     1
#       3.08        272378     1
#       3.60        319039     1
#       5.55        491674     1
#       5.95        526937     1
#                             ..
# 2019  5.45        1111697    1
#       6.05        1233886    1
#       12.93       2635810    1
#       25.83       5266510    1
#       37.27       7596610    1
# Name: Political Party, Length: 191, dtype: int64

# %% [markdown]
# ### 15.Show the total number votes of each year in Pie Chart

# %%
ele1.groupby('year').count()['Votes'].plot(kind='pie')
# Out:
# <Axes: ylabel='Votes'>

# %% [markdown]
# ### 16.create a count plot for Seats Won.

# %%
ele1['Seats Won'].value_counts()
# Out:
# 0     135
# 1      24
# 2      14
# 3       3
# 13      3
# 8       3
# 4       2
# 5       2
# 11      1
# 6       1
# 14      1
# 12      1
# 15      1
# Name: Seats Won, dtype: int64

# %%
ele1['Seats Won'].value_counts(normalize=True)
ele1['Seats Won'].value_counts(dropna=False).plot.bar(color='pink')
plt.xlabel('Seats Won')
plt.ylabel('count')
plt.show()

# %% [markdown]
# ### 17.Show the total number Percentage in Pie Chart

# %%
ele1.plot(kind="bar", color='lawngreen')
plt.title('Comparison of Percentage')
plt.xlabel('Percentage')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
# ### 18.Show the total number No of Candidates in Pie Chart

# %%
r=ele1['No of Candidates'].value_counts()
r
# Out:
# 1      67
# 2      36
# 4      17
# 3      12
# 5       7
# 20      4
# 14      4
# 15      4
# 17      4
# 10      4
# 16      3
# 19      3
# 8       3
# 9       3
# 6       2
# 7       2
# 11      2
# 13      2
# 105     1
# 66      1
# 115     1
# 18      1
# 102     1
# 84      1
# 103     1
# 12      1
# 23      1
# 131     1
# 52      1
# 113     1
# Name: No of Candidates, dtype: int64

# %%
ele1['No of Candidates'].value_counts().plot(kind='pie',colors=['lawngreen','cyan'],autopct='%1.2f%%')
# Out:
# <Axes: ylabel='No of Candidates'>

# %% [markdown]
# ### 19.Show the total number Votes in Pie Chart

# %%
ele1['Votes'].value_counts()
# Out:
# 637206    1
# 3726      1
# 208393    1
# 1849      1
# 404962    1
#          ..
# 3024      1
# 572285    1
# 715222    1
# 342796    1
# 1628      1
# Name: Votes, Length: 191, dtype: int64

# %%
ele1.plot(kind='bar', color='orchid')
plt.title('Comparison of Votes')
plt.xlabel('Votes')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
# ### 20.Show the total number year in Pie Chart

# %%
ele1.describe()
# Out:
#        No of Candidates   Seats Won         Votes   Percentage         year
# count        191.000000  191.000000  1.910000e+02   191.000000   191.000000
# mean           9.089005    1.047120  7.415260e+05    26.485916  2000.958115
# std           20.922097    2.715042  1.391167e+06   207.108900    13.680887
# min            1.000000    0.000000  2.610000e+02     0.000000  1977.000000
# 25%            1.000000    0.000000  1.120250e+04     0.060000  1986.000000
# 50%            2.000000    0.000000  2.585910e+05     2.070000  2004.000000
# 75%            7.500000    1.000000  6.402860e+05     5.470000  2014.000000
# max          131.000000   15.000000  7.596610e+06  2053.000000  2019.000000

# %%
ele1['No of Candidates'].value_counts()
# Out:
# 1      67
# 2      36
# 4      17
# 3      12
# 5       7
# 20      4
# 14      4
# 15      4
# 17      4
# 10      4
# 16      3
# 19      3
# 8       3
# 9       3
# 6       2
# 7       2
# 11      2
# 13      2
# 105     1
# 66      1
# 115     1
# 18      1
# 102     1
# 84      1
# 103     1
# 12      1
# 23      1
# 131     1
# 52      1
# 113     1
# Name: No of Candidates, dtype: int64

# %%
ele1['No of Candidates'].value_counts().plot.bar(figsize=(20,5))
plt.title('Comparison of No of Candidates')
plt.xlabel('No of Candidates')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
ele1['Seats Won'].value_counts().plot.bar(figsize=(20,5), color='green')
plt.title('Comparison of Seats Won')
plt.xlabel('Seats Won')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
ele1['Percentage'].value_counts().plot.bar(figsize=(20,5), color='magenta')
plt.title('Comparison of Percentage')
plt.xlabel('Percentage')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
#scatterplot
sns.pairplot(ele1)

# %%
#correlation
ele1.corr()
# Out:
# C:\Users\vantl\AppData\Local\Temp\ipykernel_1804\3632822729.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ele1.corr()
#                   No of Candidates  Seats Won     Votes  Percentage      year
# No of Candidates          1.000000   0.047828  0.107363   -0.035744 -0.003683
# Seats Won                 0.047828   1.000000  0.824325    0.016882 -0.112169
# Votes                     0.107363   0.824325  1.000000    0.011075 -0.025085
# Percentage               -0.035744   0.016882  0.011075    1.000000 -0.040076
# year                     -0.003683  -0.112169 -0.025085   -0.040076  1.000000

# %%
#heatmap 
sns.heatmap(ele1.corr(), annot=True, cmap='RdYlGn', square=True)
# Out:
# C:\Users\vantl\AppData\Local\Temp\ipykernel_1804\1587888708.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(ele1.corr(), annot=True, cmap='RdYlGn', square=True)
# <Axes: >

# %%
#Histogram
ele1.hist(color='brown')
plt.show()

# %% [markdown]
# ### Write an inference

# %% [markdown]
# •	This is a Indian parliament elections
#
# •	There are 191 rows and 8 columns.
#
# •	There is null values in the data.
#
# •	191 is the total number of party
#
# •	122 is the unique number of party
#
# •	Which more year in 2014 (28) and least in 1977(11)
#
# •	7596610 is the maximum votes
#
# •	261 is the minimum votes
#
# •	7596349 is the range of votes.
#
# •	741526.005 is the average of votes
#
# •	1391167.113 is the standard deviation of votes
#
# •	15.00 is the maximum seats won
#
# •	0 is the minimum seats won
#
# •	1.05 is the average of seats won
#
# •	2.72 is the standard deviation of votes
#
# •	2053.00 is the maximum percentage
#
# •	0 is the minimum percentage
#
# •	126.49 is the average of percentage
#
# •	207.109 is the standard deviation of percentage
